# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# LAE lists

W24lst = [\
    # From White+24 https://arxiv.org/pdf/2406.01803
    {'z':2.40,'dz':0.06,'r0':3.0,'dr0':0.2},\
    {'z':3.12,'dz':0.06,'r0':3.0,'dr0':0.2},\
]
K19lst = [\
  # From Khostovan+19 https://arxiv.org/pdf/1811.00556.pdf
  {'z':2.51,'dz':0.08,'r0':4.13,'dr0':0.42},\
  {'z':2.81,'dz':0.09,'r0':7.24,'dr0':0.75},\
  {'z':2.99,'dz':0.09,'r0':3.85,'dr0':0.46},\
  {'z':3.17,'dz':0.09,'r0':3.62,'dr0':0.52},\
  {'z':3.33,'dz':0.10,'r0':3.89,'dr0':0.43},\
  {'z':3.74,'dz':0.11,'r0':9.56,'dr0':1.38},\
  {'z':4.13,'dz':0.12,'r0':7.49,'dr0':1.20},\
  {'z':4.58,'dz':0.14,'r0':10.8,'dr0':1.73},\
]
H19lst = [\
  # From https://ui.adsabs.harvard.edu/abs/2019MNRAS.483.3950H/abstract
  {'z':2.67,'dz':0.00,'r0':4.1,'dr0':0.2},\
]
H18lst = [\
  # From https://ui.adsabs.harvard.edu/abs/2018ApJ...864..145H/abstract
  {'z':2.23,'dz':0.00,'r0':3.66,'dr0':0.47},\
]
K18lst = [\
  # From https://ui.adsabs.harvard.edu/abs/2018PASJ...70....4K/abstract
  {'z':2.18,'dz':0.00,'r0':2.78,'dr0':0.67},\
  {'z':2.18,'dz':0.00,'r0':2.56,'dr0':0.45},\
]
B16lst = [\
  # From https://ui.adsabs.harvard.edu/abs/2016MNRAS.456.4061B/abstract
  {'z':3.09,'dz':0.00,'r0':2.86,'dr0':0.33},\
]
O10lst = [\
  # From Ouchi+10 https://arxiv.org/pdf/1007.2961.pdf
  {'z':3.10,'dz':0.10,'r0':1.70,'dr0':0.43},\
  {'z':3.70,'dz':0.10,'r0':2.74,'dr0':0.65},\
]
G07lst = [\
  # From Gawiser+07 https://arxiv.org/abs/0710.2697
  {'z':3.10,'dz':0.00,'r0':3.60,'dr0':0.90},\
]
K07lst = [\
  # From Kovac+07 https://arxiv.org/abs/0706.0893
  {'z':4.50,'dz':0.00,'r0':4.61,'dr0':0.60},\
]

# %%
# LBG lists

# Hildebrandt+09 
H09lst = [
    # u-dropouts  (magmin = 23)
    {'z': 3.28, 'dz': 0.00, 'magmin': 23.0, 'maglim': 24.5, 'r0': 5.03, 'dr0': 0.35},
    {'z': 3.28, 'dz': 0.00, 'magmin': 23.0, 'maglim': 25.0, 'r0': 3.47, 'dr0': 0.13},
    {'z': 3.28, 'dz': 0.00, 'magmin': 23.0, 'maglim': 25.5, 'r0': 2.76, 'dr0': 0.08},
    # g-dropouts  (magmin = 23.5)
    {'z': 3.87, 'dz': 0.00, 'magmin': 23.5, 'maglim': 25.0, 'r0': 5.43, 'dr0': 0.39},
    {'z': 3.87, 'dz': 0.00, 'magmin': 23.5, 'maglim': 25.5, 'r0': 4.64, 'dr0': 0.27},
    {'z': 3.87, 'dz': 0.00, 'magmin': 23.5, 'maglim': 26.0, 'r0': 3.69, 'dr0': 0.13},
    # r-dropouts  (magmin = 24)
    {'z': 4.74, 'dz': 0.00, 'magmin': 24.0, 'maglim': 25.5, 'r0': 5.22, 'dr0': 0.38},
    {'z': 4.74, 'dz': 0.00, 'magmin': 24.0, 'maglim': 26.0, 'r0': 4.07, 'dr0': 0.18},
    {'z': 4.74, 'dz': 0.00, 'magmin': 24.0, 'maglim': 26.5, 'r0': 3.45, 'dr0': 0.10},
]
# Bian+13
B13lst = [
    {'z': 2.9, 'dz': 0.0, 'magmin': 23.5, 'maglim': 24.0, 'r0': 5.77, 'dr0': 0.36},
    {'z': 2.9, 'dz': 0.0, 'magmin': 24.0, 'maglim': 24.5, 'r0': 5.14, 'dr0': 0.16},
]

# Bielby+11 https://ui.adsabs.harvard.edu/abs/2011MNRAS.414....2B/abstract
B11lst = [
    {'z': 2.85, 'dz': 0.34, 'magmin': 23.0, 'maglim': 25.5, 'r0': 3.67, 'dr0': 0.24},
]

# Durkalec+15
D15lst = [
    {'z': 2.50, 'dz': 0.45, 'magmin': 22.5, 'maglim': 25.0, 'r0': 3.95, 'dr0': 0.51},
    {'z': 3.47, 'dz': 1.05, 'magmin': 22.5, 'maglim': 25.0, 'r0': 4.35, 'dr0': 0.68},
]

# %%
# This work
E25lst = [
    {'z': 2.50, 'dz': 0.00,'r0': 3.28, 'dr0': 3.98-3.28},
    {'z': 3.00, 'dz': 0.00,'r0': 4.13, 'dr0': 4.37-4.13},

]
E25wlst = [
    {'z': 2.50, 'dz': 0.00,'r0': 3.08, 'dr0': .8},
    {'z': 3.00, 'dz': 0.00,'r0': 3.85, 'dr0': 4.53-3.85},

]

# %%
4.53-3.85
# Out:
# 0.6800000000000002

# %%
def plot_r0():
    """Does the work."""
    fig,ax = plt.subplots(1,1,figsize=(8,4))
    zz = [x[  'z'] for x in W24lst]
    r0 = [x[ 'r0'] for x in W24lst]
    dr = [x['dr0'] for x in W24lst]
    ax.errorbar(zz,r0,yerr=dr,fmt='s',color='C0',mfc='None',label='W+24')
    # Then Khostovan+19
    zz = [x[  'z'] for x in K19lst]
    r0 = [x[ 'r0'] for x in K19lst]
    dr = [x['dr0'] for x in K19lst]
    ax.errorbar(zz,r0,yerr=dr,fmt='s',color='C1',mfc='None',label='K+19')
    # Then Hong+19
    zz = [x[  'z'] for x in H19lst]
    r0 = [x[ 'r0'] for x in H19lst]
    dr = [x['dr0'] for x in H19lst]
    ax.errorbar(zz,r0,yerr=dr,fmt='d',color='C2',mfc='None',label='H+19')
    # Then Hao+18
    zz = [x[  'z'] for x in H18lst]
    r0 = [x[ 'r0'] for x in H18lst]
    dr = [x['dr0'] for x in H18lst]
    ax.errorbar(zz,r0,yerr=dr,fmt='d',color='C3',mfc='None',label='H+18')
    # Then Kuskaba+18
    zz = [x[  'z'] for x in K18lst]
    r0 = [x[ 'r0'] for x in K18lst]
    dr = [x['dr0'] for x in K18lst]
    ax.errorbar(zz,r0,yerr=dr,fmt='d',color='C4',mfc='None',label='K+18')
    # Then Bielby+16
    zz = [x[  'z'] for x in B16lst]
    r0 = [x[ 'r0'] for x in B16lst]
    dr = [x['dr0'] for x in B16lst]
    ax.errorbar(zz,r0,yerr=dr,fmt='d',color='C5',mfc='None',label='B+16')
    # Then Ouchi+10
    zz = [x[  'z'] for x in O10lst]
    r0 = [x[ 'r0'] for x in O10lst]
    dr = [x['dr0'] for x in O10lst]
    ax.errorbar(zz,r0,yerr=dr,fmt='d',color='C6',mfc='None',label='O+10')
    # Then Gawiser+07
    zz = [x[  'z'] for x in G07lst]
    r0 = [x[ 'r0'] for x in G07lst]
    dr = [x['dr0'] for x in G07lst]
    ax.errorbar(zz,r0,yerr=dr,fmt='d',color='C7',mfc='None',label='G+07')
    # Then Kovac+07
    zz = [x[  'z'] for x in K07lst]
    r0 = [x[ 'r0'] for x in K07lst]
    dr = [x['dr0'] for x in K07lst]
    ax.errorbar(zz,r0,yerr=dr,fmt='d',color='C8',mfc='None',label='K+07')

    zz = [x[  'z'] for x in D15lst]
    r0 = [x[ 'r0'] for x in D15lst]
    dr = [x['dr0'] for x in D15lst]
    ax.errorbar(zz,r0,yerr=dr,fmt='s',color='C0',mfc='None',label='D+15')

    zz = [x[  'z'] for x in B13lst]
    r0 = [x[ 'r0'] for x in B13lst]
    dr = [x['dr0'] for x in B13lst]
    ax.errorbar(zz,r0,yerr=dr,fmt='s',color='C1',mfc='None',label='B+13')

    zz = [x[  'z'] for x in B11lst]
    r0 = [x[ 'r0'] for x in B11lst]
    dr = [x['dr0'] for x in B11lst]
    ax.errorbar(zz,r0,yerr=dr,fmt='s',color='C2',mfc='None',label='B+11')
    
    zz = [x[  'z'] for x in H09lst]
    r0 = [x[ 'r0'] for x in H09lst]
    dr = [x['dr0'] for x in H09lst]
    ax.errorbar(zz,r0,yerr=dr,fmt='s',color='C4',mfc='None',label='H+09')

    
    #
    ax.legend(loc=2,ncol=2)
    ax.set_xlim(2.1,4.75)
    ax.set_ylim(0.0,12.0)
    ax.set_xlabel(r'$z$')
    ax.set_ylabel(r'$r_0\quad [h^{-1}{\rm Mpc}]$')
    #
    plt.tight_layout()
    plt.savefig("plots/lae_r0.pdf")
    # plt.savefig("lae_r0.png")
    #

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D


def plot_r0(show_yerr=True):
    """
    Plot r0–z diagram.

    Symbols
    -------
    LAE  : filled diamonds (C0) – one point per *list*
    E25  : filled stars    (C7) – one point per *datum*
    LBG  : filled squares         – one point per *datum*
           colour encodes m_UV  = 24, 24.5, 25, 25.5, 26, 26.5
           (C1 … C6 respectively)

    Legends
    -------
    • upper-left : ‘LAE’, ‘E25’
    • lower-left : all LBG magnitude-limit keys under the title “LBG”

    Parameters
    ----------
    show_yerr : bool  (default: True)
        If False the vertical error bars are suppressed.
    """

    # ----------------------------------------------------------
    # Helper: draw one or several points with / without y-errors
    # ----------------------------------------------------------
    def draw(ax, z, r0, dr0, *, marker, colour, ms=6, label=None,zorder=2,mfc=-1):
        yerr = dr0 if show_yerr else None
        ax.errorbar(z, r0, yerr=yerr,
                    fmt=marker, markersize=ms,
                    color=colour, mfc=colour if mfc==-1 else None, linestyle='none',
                    label=label,zorder=zorder)

    # ----------------------------------------------------------
    # Data sets  (must already exist in the namespace)
    # ----------------------------------------------------------
    lae_sets = [
        (W24lst, 'W+24'), (K19lst, 'K+19'),
        (H19lst, 'H+19'), (H18lst, 'H+18'), (K18lst, 'K+18'),
        (B16lst, 'B+16'), (O10lst, 'O+10'),
        (G07lst, 'G+07'), (K07lst, 'K+07')
    ]

    lbg_sets = [H09lst, B13lst, B11lst, D15lst]     # point-by-point
    e25_set  = E25lst                               # point-by-point, star
    e25w_set  = E25wlst                               # point-by-point, star

    # colour scheme for LBG magnitude limits  (ordered!)
    mag_order     = [24.0, 24.5, 25.0, 25.5]#, 26.0, 26.5]
    colour_by_mag = {24.0: 'C1', 24.5: 'C2', 25.0: 'C3',
                     25.5: 'C4', 26.0: 'C5', 26.5: 'C6'}

    # ----------------------------------------------------------
    # Figure / axis
    # ----------------------------------------------------------
    fig, ax = plt.subplots(figsize=(6,3))

    # -------- E25 -------------------------------------------------------
    first_e25 = True
    draw(ax,[],[],None,
            marker='*', colour='k', ms=11,
            label='This work' if first_e25 else None, zorder=10)
    first_e25 = False
    for d in e25_set:
        draw(ax, d['z'], d['r0'], d['dr0'],
             marker='*', colour='k', ms=11,
             label='This work' if first_e25 else None, zorder=10)
        first_e25 = False
        
    # # -------- E25 -------------------------------------------------------
    # first_e25w = True
    # for d in e25w_set:
    #     draw(ax, d['z'], d['r0'], d['dr0'],
    #          marker='*', colour='k', ms=10,mfc=None,
    #          label='This work (wide)' if first_e25 else None, zorder=10)
    #     first_e25w = False

    
    # -------- LAEs ------------------------------------------------------
    first_lae = True
    draw(ax, [],[],None,
            marker='d', colour='C0',
            label='LAE' if first_lae else None)
    first_lae = False
    for data, _ in lae_sets:
        z   = [d['z']   for d in data]
        r0  = [d['r0']  for d in data]
        dr0 = [d['dr0'] for d in data]
        draw(ax, z, r0, dr0,
             marker='d', colour='C0',
             label='LAE' if first_lae else None)
        first_lae = False


    # -------- LBGs (plotted, but labels handled via proxy symbols) ------
    for lst in lbg_sets:
        for d in lst:
            ml = round(d['maglim'], 1)
            draw(ax, d['z'], d['r0'], d['dr0'],
                 marker='s', colour=colour_by_mag.get(ml, 'k'))

    # ----------------------------------------------------------
    # Build the two separate legends
    # ----------------------------------------------------------
    # handles / labels already present for LAE & E25
    handles, labels = ax.get_legend_handles_labels()
    handles_lae = []; labels_lae = []
    for h, l in zip(handles, labels):
        if l in ('LAE', 'This work'):
            handles_lae.append(h)
            labels_lae.append(l)

    # upper-left legend  (LAE & E25)
    legend_lae = ax.legend(handles_lae, labels_lae,
                           loc='upper left', frameon=True,handlelength=1)

    # Proxy handles for LBG magnitude limits (ordered)
    handles_lbg = [
        Line2D([], [], marker='s', linestyle='none',
               color=colour_by_mag[ml], markerfacecolor=colour_by_mag[ml])
        for ml in mag_order
    ]
    labels_lbg = [rf'${ml}$' for ml in mag_order]

    legend_lbg = ax.legend(handles_lbg, labels_lbg, title='LBG, $m_{UV}$',
                           loc='lower left', frameon=True,ncol=4,handlelength=1)

    # Make sure the first legend is kept
    ax.add_artist(legend_lae)

    # ----------------------------------------------------------
    # Axis cosmetics
    # ----------------------------------------------------------
    ax.set_xlim(2.15, 3.5)
    ax.set_ylim(0.0, 7.5)
    ax.set_xlabel(r'$z$')
    ax.set_ylabel(r'$r_0\;[h^{-1}\,\mathrm{Mpc}]$')

    fig.tight_layout()
    fig.savefig('plots/r0_summary.pdf')
    # fig.savefig('plots/tmp.pdf')
    # fig.savefig('plots/lae_r0.png')

# %%
plot_r0(show_yerr=True)
